# %% [markdown]
# # Working On...

# %%
import sys
from PyQt6.QtGui import *
from PyQt6.QtWidgets import *
from PyQt6.QtCore import *
import cv2
from ArduinoWindow import*
from CameraWindow import *

class GyroSpin_App(QWidget):
    def __init__(self):
        super(GyroSpin_App, self).__init__()
        #self.resize(1000, 1000)

        self.setWindowTitle("Main Menu - GyroSpin App")

        #---   Layout total ---#
        self.LayoutTotal = QHBoxLayout()
        #self.LayoutTotal.setContentsMargins(0, 0, 0, 0)
        
        #---   Layout des commandes ---#
        
        
        
        self.VBL_Buttons = QVBoxLayout()
        self.HBL_Time = QHBoxLayout()
        self.HBL_Total_Time = QVBoxLayout()
        self.HBL_Check_Boxes = QHBoxLayout()
        
        
        self.Label_Time_Edit = QLabel()
        self.Label_Time_Edit.setText(r'Time interval (ms) : ')
        self.Time_Line_Edit = QLineEdit()
        self.HBL_Time.addWidget(self.Label_Time_Edit)
        self.HBL_Time.addWidget(self.Time_Line_Edit)
        

        
        self.Time_Edit_Button = QPushButton("Edit Time Interval")
        self.Time_Edit_Button.clicked.connect(self.EditTimeStep)
        
        self.HBL_Total_Time.addLayout(self.HBL_Time)
        self.HBL_Total_Time.addWidget(self.Time_Edit_Button)
        
        self.VBL_Buttons.addLayout(self.HBL_Total_Time)

        # horizontal spaces
        self.Empty_Space1 = QLabel()
        self.VBL_Buttons.addWidget(self.Empty_Space1)

        self.OpenArduinoWidget = QPushButton("Open Arduino \n control panel")
        self.OpenArduinoWidget.clicked.connect(self.OpenArduinoSettings)
        self.VBL_Buttons.addWidget(self.OpenArduinoWidget)

        self.Empty_Space2 = QLabel()
        self.VBL_Buttons.addWidget(self.Empty_Space2)


        self.OpenCameraWidget = QPushButton("Edit Advanced \n Camera settings")
        self.OpenCameraWidget.clicked.connect(self.OpenCameraSettings)
        self.VBL_Buttons.addWidget(self.OpenCameraWidget)
        

        self.Empty_Space3 = QLabel()
        self.VBL_Buttons.addWidget(self.Empty_Space3)



        self.LabelDetection = QLabel("Message for detection...")
        self.VBL_Buttons.addWidget(self.LabelDetection)


        self.Empty_Space4 = QLabel()
        self.VBL_Buttons.addWidget(self.Empty_Space4)

        
        
        self.save_plots = QCheckBox("Save plots")
        #self.save_plots.setText("Save plots")
        self.save_data = QCheckBox("Save data")
        #self.save_data.setText("Save data")
        self.HBL_Check_Boxes.addWidget(self.save_plots)
        self.HBL_Check_Boxes.addWidget(self.save_data)
        self.VBL_Buttons.addLayout(self.HBL_Check_Boxes)

        self.Empty_Space5 = QLabel()
        self.VBL_Buttons.addWidget(self.Empty_Space5)


        
        #--- Esthétique---#
        self.fig = QLabel()
        #pixmap = QPixmap('Fig_Interface.png')
        pixmap = QPixmap('dessin.svg')
        #pixmap = pixmap.scaled(200, 200)
        self.fig.setPixmap(pixmap)
        self.VBL_Buttons.addWidget(self.fig)
        '''
        self.FigLayout = QHBoxLayout()
        self.fig1 = QLabel()
        self.fig2 = QLabel()
        pixmap1 = QPixmap('LOGO SPRINT SU.jpeg')
        pixmap2 = QPixmap('HQC Logo.png')
        pixmap1 = pixmap1.scaled(200, 200)
        pixmap2 = pixmap2.scaled(200, 200)
        self.fig1.setPixmap(pixmap1)
        self.fig2.setPixmap(pixmap2)
        print(pixmap1.width(), pixmap1.height)
        print(pixmap2.width(), pixmap2.height())
        self.fig1.resize(160, 160)
        self.fig2.resize(160, 160)
        #self.fig1.resize(10, 10)
        #self.fig2.resize(10, 10)
        self.FigLayout.addWidget(self.fig1)
        self.FigLayout.addWidget(self.fig2)
        
        self.VBL_Buttons.addLayout(self.FigLayout)
        '''        
        
        
        
        #---   Layout caméra ---#

        self.VBL = QVBoxLayout()

        self.FeedLabel_cam1 = QLabel()
        self.FeedLabel_cam2 = QLabel()
        self.VBL.addWidget(self.FeedLabel_cam1)
        self.VBL.addWidget(self.FeedLabel_cam2)

        
        self.Cam_Control_Grid = QGridLayout()
        self.Enable_cam1 = QPushButton("Enable Cam1")
        self.Enable_cam2 = QPushButton("Enable Cam2")
        self.Disable_cam1 = QPushButton("Disable Cam1")
        self.Disable_cam2 = QPushButton("Disable Cam2")

        self.Enable_cam1.clicked.connect(self.Set_cam1)
        self.Enable_cam2.clicked.connect(self.Set_cam2)
        self.Disable_cam1.clicked.connect(self.Stop_cam1)
        self.Disable_cam2.clicked.connect(self.Stop_cam2)

        self.Cam_Control_Grid.addWidget(self.Enable_cam1, 0, 0, 1, 1)
        self.Cam_Control_Grid.addWidget(self.Enable_cam2, 0, 1, 1, 1)
        self.Cam_Control_Grid.addWidget(self.Disable_cam1, 1, 0, 1, 1)
        self.Cam_Control_Grid.addWidget(self.Disable_cam2, 1, 1, 1, 1)

        self.VBL.addLayout(self.Cam_Control_Grid)

        self.Worker1 = Worker1()
        self.Worker2 = Worker2()
        
        self.Worker1.start()
        self.Worker2.start()
        
        self.Worker1.ImageUpdate.connect(self.ImageUpdateSlot_1)
        self.Worker2.ImageUpdate.connect(self.ImageUpdateSlot_2)
        
        
        self.LayoutTotal.addLayout(self.VBL)
        self.LayoutTotal.addLayout(self.VBL_Buttons)

        self.setLayout(self.LayoutTotal)
        
        #---   VALUES ?!?

        self.default_time_step = 1
        self.DefaultTimeStep()

    def DefaultTimeStep(self):
        self.time_step = self.default_time_step
        self.Time_Line_Edit.setText(str(self.time_step))
        
        
        
    def EditTimeStep(self):
        try:
            self.time_step = int(self.Time_Line_Edit.text())
            print("Successful change of time step")
            print(self.time_step)
        except:
            self.DefaultTimeStep()
            print("Invalid value of time step entered...")
            print("Setting back to default value")
            
        


    

    def ImageUpdateSlot_1(self, Image1):
        self.FeedLabel_cam1.setPixmap(QPixmap.fromImage(Image1))

    def ImageUpdateSlot_2(self, Image2):
        self.FeedLabel_cam2.setPixmap(QPixmap.fromImage(Image2))

    def Stop_cam1(self):
        self.Worker1.stop()
        
    def Stop_cam2(self):
        self.Worker2.stop()

    def Set_cam1(self):
        self.Worker1.set()
        
    def Set_cam2(self):
        self.Worker2.set()

    def OpenArduinoSettings(self):
        self.ArduinoSetting_Window = ArduinoSettings_Widget()
        self.ArduinoSetting_Window.show()
        
    def OpenCameraSettings(self):
        self.CameraSetting_Window = CamSettings_Widget()
        self.CameraSetting_Window.show()

    
        

class Worker1(QThread):
    ImageUpdate = pyqtSignal(QImage)
    def run(self):
        self.ThreadActive = True
        Capture = cv2.VideoCapture(0)
        while self.ThreadActive:
            ret, frame = Capture.read()
            if ret:
                Image1 = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                FlippedImage1 = cv2.flip(Image1, 1)
                ConvertToQtFormat1 = QImage(FlippedImage1.data, FlippedImage1.shape[1], FlippedImage1.shape[0], QImage.Format.Format_RGB888)
                Pic1 = ConvertToQtFormat1.scaled(420, 300)
                #Pic = ConvertToQtFormat.scaled(640, 480)
                self.ImageUpdate.emit(Pic1)
    def stop(self):
        self.ThreadActive = False
        self.quit()

    def set(self):
        '''A corriger'''
        self.ThreadActive = True
        self.run()



class Worker2(QThread):
    ImageUpdate = pyqtSignal(QImage)
    def run(self):
        self.ThreadActive = True
        Capture = cv2.VideoCapture(0)
        while self.ThreadActive:
            ret, frame = Capture.read()
            if ret:
                Image2 = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                FlippedImage2 = cv2.flip(Image2, 1)
                ConvertToQtFormat2 = QImage(FlippedImage2.data, FlippedImage2.shape[1], FlippedImage2.shape[0], QImage.Format.Format_RGB888)
                Pic2 = ConvertToQtFormat2.scaled(420, 300)
                self.ImageUpdate.emit(Pic2)
    def stop(self):
        self.ThreadActive = False
        self.quit()

    def set(self):
        '''A corriger'''
        self.ThreadActive = True
        self.run()

# %%
if __name__ == "__main__":
    App = QApplication(sys.argv)
    Root = GyroSpin_App()
    Root.show()
    sys.exit(App.exec())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /Users/bradaizakaria/Documents/venvL3/envL3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3534: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
help(QPixmap)
# Out:
# Help on class QPixmap in module PyQt6.QtGui:
#
# class QPixmap(QPaintDevice)
#  |  QPixmap()
#  |  QPixmap(w: int, h: int)
#  |  QPixmap(a0: QSize)
#  |  QPixmap(fileName: str, format: typing.Optional[str] = None, flags: Qt.ImageConversionFlag = Qt.AutoColor)
#  |  QPixmap(xpm: List[str])
#  |  QPixmap(a0: QPixmap)
#  |  QPixmap(variant: Any)
#  |
#  |  Method resolution order:
#  |      QPixmap
#  |      QPaintDevice
#  |      PyQt6.sip.simplewrapper
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  cacheKey(...) from PyQt6.sip.wrappertype
#  |      cacheKey(self) -> int
#  |
#  |  convertFromImage(...) from PyQt6.sip.wrappertype
#  |      convertFromImage(self, img: QImage, flags: Qt.ImageConversionFlag = Qt.AutoColor) -> bool
#  |
#  |  copy(...) from PyQt6.sip.wrappertype
#  |      copy(self, rect: QRect = QRect()) -> QPixmap
#  |      copy(self, ax: int, ay: int, awidth: int, aheight: int) -> QPixmap
#  |
#  |  createHeuristicMask(...) from PyQt6.sip.wrappertype
#  |      createHeuristicMask(self, clipTight: bool = True) -> QBitmap
#  |
#  |  createMaskFromColor(...) from PyQt6.sip.wrappertype
#  |      createMaskFromColor(self, maskColor: Union[QColor, Qt.GlobalColor, int, QGradient], mode: Qt.MaskMode = Qt.MaskInColor) -> QBitmap
#  |
#  |  defaultDepth(...) from PyQt6.sip.wrappertype
#  |      defaultDepth() -> int
#  |
#  |  depth(...) from PyQt6.sip.wrappertype
#  |      depth(self) -> int
#  |
#  |  detach(...) from PyQt6.sip.wrappertype
#  |      detach(self)
#  |
#  |  devType(...) from PyQt6.sip.wrappertype
#  |      devType(self) -> int
#  |
#  |  deviceIndependentSize(...) from PyQt6.sip.wrappertype
#  |      deviceIndependentSize(self) -> QSizeF
#  |
#  |  devicePixelRatio(...) from PyQt6.sip.wrappertype
#  |      devicePixelRatio(self) -> float
#  |
#  |  fill(...) from PyQt6.sip.wrappertype
#  |      fill(self, color: Union[QColor, Qt.GlobalColor, int, QGradient] = Qt.white)
#  |
#  |  fromImage(...) from PyQt6.sip.wrappertype
#  |      fromImage(image: QImage, flags: Qt.ImageConversionFlag = Qt.AutoColor) -> QPixmap
#  |
#  |  fromImageReader(...) from PyQt6.sip.wrappertype
#  |      fromImageReader(imageReader: QImageReader, flags: Qt.ImageConversionFlag = Qt.AutoColor) -> QPixmap
#  |
#  |  hasAlpha(...) from PyQt6.sip.wrappertype
#  |      hasAlpha(self) -> bool
#  |
#  |  hasAlphaChannel(...) from PyQt6.sip.wrappertype
#  |      hasAlphaChannel(self) -> bool
#  |
#  |  height(...) from PyQt6.sip.wrappertype
#  |      height(self) -> int
#  |
#  |  isNull(...) from PyQt6.sip.wrappertype
#  |      isNull(self) -> bool
#  |
#  |  isQBitmap(...) from PyQt6.sip.wrappertype
#  |      isQBitmap(self) -> bool
#  |
#  |  load(...) from PyQt6.sip.wrappertype
#  |      load(self, fileName: str, format: typing.Optional[str] = None, flags: Qt.ImageConversionFlag = Qt.AutoColor) -> bool
#  |
#  |  loadFromData(...) from PyQt6.sip.wrappertype
#  |      loadFromData(self, buf: PyQt6.sip.array[bytes], format: typing.Optional[str] = None, flags: Qt.ImageConversionFlag = Qt.AutoColor) -> bool
#  |      loadFromData(self, buf: QByteArray, format: typing.Optional[str] = None, flags: Qt.ImageConversionFlag = Qt.AutoColor) -> bool
#  |
#  |  mask(...) from PyQt6.sip.wrappertype
#  |      mask(self) -> QBitmap
#  |
#  |  metric(...) from PyQt6.sip.wrappertype
#  |      metric(self, a0: QPaintDevice.PaintDeviceMetric) -> int
#  |
#  |  paintEngine(...) from PyQt6.sip.wrappertype
#  |      paintEngine(self) -> QPaintEngine
#  |
#  |  rect(...) from PyQt6.sip.wrappertype
#  |      rect(self) -> QRect
#  |
#  |  save(...) from PyQt6.sip.wrappertype
#  |      save(self, fileName: str, format: typing.Optional[str] = None, quality: int = -1) -> bool
#  |      save(self, device: QIODevice, format: typing.Optional[str] = None, quality: int = -1) -> bool
#  |
#  |  scaled(...) from PyQt6.sip.wrappertype
#  |      scaled(self, width: int, height: int, aspectRatioMode: Qt.AspectRatioMode = Qt.IgnoreAspectRatio, transformMode: Qt.TransformationMode = Qt.FastTransformation) -> QPixmap
#  |      scaled(self, size: QSize, aspectRatioMode: Qt.AspectRatioMode = Qt.IgnoreAspectRatio, transformMode: Qt.TransformationMode = Qt.FastTransformation) -> QPixmap
#  |
#  |  scaledToHeight(...) from PyQt6.sip.wrappertype
#  |      scaledToHeight(self, height: int, mode: Qt.TransformationMode = Qt.FastTransformation) -> QPixmap
#  |
#  |  scaledToWidth(...) from PyQt6.sip.wrappertype
#  |      scaledToWidth(self, width: int, mode: Qt.TransformationMode = Qt.FastTransformation) -> QPixmap
#  |
#  |  scroll(...) from PyQt6.sip.wrappertype
#  |      scroll(self, dx: int, dy: int, rect: QRect) -> QRegion
#  |      scroll(self, dx: int, dy: int, x: int, y: int, width: int, height: int) -> QRegion
#  |
#  |  setDevicePixelRatio(...) from PyQt6.sip.wrappertype
#  |      setDevicePixelRatio(self, scaleFactor: float)
#  |
#  |  setMask(...) from PyQt6.sip.wrappertype
#  |      setMask(self, a0: QBitmap)
#  |
#  |  size(...) from PyQt6.sip.wrappertype
#  |      size(self) -> QSize
#  |
#  |  swap(...) from PyQt6.sip.wrappertype
#  |      swap(self, other: QPixmap)
#  |
#  |  toImage(...) from PyQt6.sip.wrappertype
#  |      toImage(self) -> QImage
#  |
#  |  transformed(...) from PyQt6.sip.wrappertype
#  |      transformed(self, transform: QTransform, mode: Qt.TransformationMode = Qt.FastTransformation) -> QPixmap
#  |
#  |  trueMatrix(...) from PyQt6.sip.wrappertype
#  |      trueMatrix(m: QTransform, w: int, h: int) -> QTransform
#  |
#  |  width(...) from PyQt6.sip.wrappertype
#  |      width(self) -> int
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from QPaintDevice:
#  |
#  |  colorCount(...) from PyQt6.sip.wrappertype
#  |      colorCount(self) -> int
#  |
#  |  devicePixelRatioF(...) from PyQt6.sip.wrappertype
#  |      devicePixelRatioF(self) -> float
#  |
#  |  devicePixelRatioFScale(...) from PyQt6.sip.wrappertype
#  |      devicePixelRatioFScale() -> float
#  |
#  |  heightMM(...) from PyQt6.sip.wrappertype
#  |      heightMM(self) -> int
#  |
#  |  logicalDpiX(...) from PyQt6.sip.wrappertype
#  |      logicalDpiX(self) -> int
#  |
#  |  logicalDpiY(...) from PyQt6.sip.wrappertype
#  |      logicalDpiY(self) -> int
#  |
#  |  paintingActive(...) from PyQt6.sip.wrappertype
#  |      paintingActive(self) -> bool
#  |
#  |  physicalDpiX(...) from PyQt6.sip.wrappertype
#  |      physicalDpiX(self) -> int
#  |
#  |  physicalDpiY(...) from PyQt6.sip.wrappertype
#  |      physicalDpiY(self) -> int
#  |
#  |  widthMM(...) from PyQt6.sip.wrappertype
#  |      widthMM(self) -> int
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from QPaintDevice:
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from QPaintDevice:
#  |
#  |  PaintDeviceMetric = <enum 'PaintDeviceMetric'>
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from PyQt6.sip.simplewrapper:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from PyQt6.sip.simplewrapper:
#  |
#  |  __new__(*args, **kwargs) from PyQt6.sip.wrappertype
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from PyQt6.sip.simplewrapper:
#  |
#  |  __dict__
