# %%
from GyroSolver import *
import numpy as np
import matplotlib.pyplot as plt
from time import time

# %%
CI = [0.001, 0, 0, 0, 0, 2*np.pi*200]


g = 9.81
m = 0.375    #######0.375
J3 = 0.000055
J1 = 0.000055
h = 31.25 * 1e-3
x0 = 150 * 1e-2 

p_psi_exp = CI[-1] * J3


#omega_f =  0.265

omega_f = m * g * h / (p_psi_exp)

params_f = [g, m, h, J1, J3, x0, -np.pi,  omega_f / (2 * np.pi)]


print(f'Larmor Pulsation (th) : {omega_f : >+20_.3f}')
print(f'Larmor Frequency (th) : {omega_f/(2*np.pi) : >+20_.3f}')
print(f'Larmor Period (th) : {2 * np.pi / omega_f : >+20_.3f}')

omega_R_th = -0.5 * np.cos(params_f[-2]) * (m * h * x0 * (omega_f**2)) / p_psi_exp
#omega_R_th = -0.5 * np.cos(params_f[-2]) * ( (m*h)**3 * g**2 * x0) / (p_psi_exp**3)

print(f'Rabi Frequency (th) : {omega_R_th : >+20_.3f}')
print(f'Rabi Period (th) : {2 * np.pi / omega_R_th : >+20_.3f}')
print(f'Temps de montée (th) : {np.pi / omega_R_th : >+20_.3f}')


rapport_freq = float(omega_f / omega_R_th)
print(f'Rapport des pulsations Larmor/Rabi : {rapport_freq : >+20_.3f}')

params_f[-1] = 0.124   # 1.06 


t1 = time()
t, the, phi, psi, the_d, phi_d, psi_d = Solve_Gyro_Forced(0, 10, CI, params_f, solving_method='RK23', forcing='XY')
t2 = time()
print('Temps de résolution', t2 - t1)

plt.figure()
plt.plot(t, the * 180 / np.pi, 'r', label='Product')
plt.xlabel(r'time $t \; (s)$')
plt.ylabel(r'$\theta \; (^\circ)$')
plt.legend()
plt.show()

plt.figure()
plt.plot(t, phi * 180 / np.pi, 'b')
plt.show()

plt.figure()
plt.plot(t[0:10], psi[0:10] * 180 / np.pi, 'g', label='Product')
plt.show()
# Out:
# Larmor Pulsation (th) :               +1.663
# Larmor Frequency (th) :               +0.265
# Larmor Period (th) :               +3.777
# Rabi Frequency (th) :               +0.352
# Rabi Period (th) :              +17.859
# Temps de montée (th) :               +8.929
# Rapport des pulsations Larmor/Rabi :               +4.728
# Temps de résolution 0.36823034286499023

# %%
tab_freq_sweep = np.arange(0.5, 2, 0.008) 
print('Estimated time :', len(tab_freq_sweep) * 0.4)

f_max, exc_freq, tab_theta, tab_theta_min, tab_t = Frequency_Sweep_MIN(tab_freq_sweep, params_f, CI, tf=20
                        , solving_method='RK23', plot=True, forcing='X')
# Out:
# Estimated time : 75.2

# %% [markdown]
# ## Looking for l'$Artefact$ :

# %%
w_pilot = params_f[-1] * 2 * np.pi
w_pilot = 0.35

w_pilot = w_pilot * 2 * np.pi

phase = params_f[-2]
plt.figure()
plt.plot(t, np.sin(t * w_pilot + phase - phi))

# %%
w_pilot = params_f[-1] * 2 * np.pi
w_pilot = 0.15

w_pilot = w_pilot * 2 * np.pi

phase = params_f[-2]
plt.figure()
plt.plot(t, np.sin(t * w_pilot + phase - phi))


w_pilot = 0.35

w_pilot = w_pilot * 2 * np.pi

phase = params_f[-2]
plt.figure()
plt.plot(t, np.sin(t * w_pilot + phase - phi))

# %%
params_f[-1] = 1.19 #529


t1 = time()
t, the, phi, psi, the_d, phi_d, psi_d = Solve_Gyro_Forced(0, 30, CI, params_f, solving_method='RK23', forcing='XY')
t_Fast, the_Fast, phi, psi, the_d, phi_d, psi_d = Solve_Gyro_Forced_Fast(0, 30, CI, params_f, solving_method='RK23', forcing='XY')

t2 = time()
print('Temps de résolution', t2 - t1)

plt.figure()
plt.plot(t, the * 180 / np.pi, 'r', label='Normal')
plt.plot(t_Fast, the_Fast * 180 / np.pi, 'b', label='Fast', alpha=0.5)
plt.xlabel(r'time $t \; (s)$')
plt.ylabel(r'$\theta \; (^\circ)$')
plt.legend()
plt.show()

plt.figure()
plt.plot(t, the - the_Fast)
plt.show()
# Out:
# Temps de résolution 0.7049479484558105
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 20
#      17 plt.show()
#      19 plt.figure()
# ---> 20 plt.plot(t, the - the_Fast)
#      21 plt.show()
#
# ValueError: operands could not be broadcast together with shapes (10000,) (3857,)

# %% [markdown]
# ## Forçage XY :

# %%
CI = [0.001, 0, 0, 0, 0, 2*np.pi*100]
g = 9.81
m = 0.375
J3 = 0.000055
J1 = 0.000055
h = 31.25 * 1e-3
x0 = 15 * 1e-2

p_psi_exp = CI[-1] * J3


#omega_f =  0.265

omega_f = m * g * h / (p_psi_exp)

params_f = [g, m, h, J1, J3, x0, -np.pi,  omega_f / (2 * np.pi)]



tab_t_burst = np.linspace(0, 15, 51, endpoint=True)
tab_freq = np.linspace(0.2, 0.8, 51, endpoint=True)
#tab_freq = np.linspace(0.7, 1.2, 51, endpoint=True)


print('Estimated time (s) :', len(tab_freq) * len(tab_t_burst) * 0.15)

t1 = time()
tab_theta, list_the, list_t = Rabi_Chevron(tab_freq, tab_t_burst, params_f, CI, forcing='XY')
t2 = time()
print(t2 - t1)

plt.figure(figsize=[10,10])
plt.imshow(np.cos(tab_theta))
plt.colorbar()
plt.xticks(np.arange(0, 51, 5), tab_t_burst[np.arange(0, 51, 5)].astype(int) ) 
plt.yticks(np.arange(0, 51, 5), tab_freq[np.arange(0, 51, 5)].round(4) ) 
plt.xlabel(r'$t_\text{burst} \; (s)$')
plt.ylabel(r'$f_\text{exc} \; (s^{-1})$')
plt.show()
# Out:
# Estimated time (s) : 390.15
# 324.74454379081726

# %%
CI = [np.pi - 0.001, 0, 0, 0, 0, 2*np.pi*100]


tab_t_burst = np.linspace(0, 15, 51, endpoint=True)
tab_freq = np.linspace(0.2, 0.8, 51, endpoint=True)
#print(tab_freq)
#print(len(tab_freq))
print('Estimated time (s) :', len(tab_freq) * len(tab_t_burst) * 0.15)

t1 = time()
tab_theta2, list_the2, list_t2 = Rabi_Chevron(tab_freq, tab_t_burst, params_f, CI, forcing='XY')
t2 = time()
print(t2 - t1)

plt.figure(figsize=[10,10])
plt.imshow(np.cos(tab_theta))
plt.colorbar()
plt.xticks(np.arange(0, 51, 5), tab_t_burst[np.arange(0, 51, 5)].astype(int) ) 
plt.yticks(np.arange(0, 51, 5), tab_freq[np.arange(0, 51, 5)].round(4) ) 
plt.xlabel(r'$t_\text{burst} \; (s)$')
plt.ylabel(r'$f_\text{exc} \; (s^{-1})$')
plt.show()
# Out:
# Estimated time (s) : 390.15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[47], line 11
#       8 print('Estimated time (s) :', len(tab_freq) * len(tab_t_burst) * 0.15)
#      10 t1 = time()
# ---> 11 tab_theta2, list_the2, list_t2 = Rabi_Chevron(tab_freq, tab_t_burst, params_f, CI, forcing='XY')
#      12 t2 = time()
#      13 print(t2 - t1)
#
# File ~/Documents/venvL3/envL3/Stage L3/Stage-LPENS/TheEND/GyroSolver.py:162, in Rabi_Chevron(exc_freq, tab_t_burst, params, CI, solving_method, forcing)
#     160 for j in range(len(tab_t_burst)):
#     161     tf = tab_t_burst[j]
# --> 162     t, theta, _, _, _, _, _ = Solve_Gyro_Forced(0, tf, CI, params, solving_method=solving_method, forcing=forcing)
#     163     #t, theta, _, _, _, _, _ = Solve_Gyro_Forced_Fast(0, tf, CI, params, solving_method=solving_method, forcing=forcing)
#     164     tab_theta[i, j] = theta[-1]
#
# File ~/Documents/venvL3/envL3/Stage L3/Stage-LPENS/TheEND/GyroSolver.py:122, in Solve_Gyro_Forced(t1, t2, CI, params, solving_method, forcing, nb_points)
#     120 p_psi = CI[-1] * J3
#     121 t = np.linspace(t1, t2, nb_points, endpoint=True)
# --> 122 ans = odeint(dSdt_forced_ODEINT, y0=CI, t=t, args=(g, m, h, J1, J3, x0, p, w, J1_, K, p_psi, forcing))
#     123 the_t = ans.T[0]
#     124 phi_t = ans.T[2]
#
# File ~/Documents/venvL3/envL3/lib/python3.11/site-packages/scipy/integrate/_odepack_py.py:242, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     240 t = copy(t)
#     241 y0 = copy(y0)
# --> 242 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     243                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     244                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     245                          int(bool(tfirst)))
#     246 if output[-1] < 0:
#     247     warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# File ~/Documents/venvL3/envL3/Stage L3/Stage-LPENS/TheEND/GyroSolver.py:106, in dSdt_forced_ODEINT(S, t, g, m, h, J1, J3, x0, p, w, J1_, K, p_psi, forcing)
#      93     return np.array([
#      94         Identity(z1),
#      95         the_dd_X(t, g, h, m, x0, p, w, J1, J3, the, phi, psi, z1, z2, z3, p_psi, J1_, K),
#    (...)
#      99         psi_dd_X(t, g, h, m, x0, p, w, J1, J3, the, phi, psi, z1, z2, z3, p_psi, J1_, K),
#     100     ])
#     101 elif forcing == 'XY':
#     102     return np.array([
#     103         Identity(z1),
#     104         the_dd_XY(t, g, h, m, x0, p, w, J1, J3, the, phi, psi, z1, z2, z3, p_psi, J1_, K),
#     105         Identity(z2),
# --> 106         phi_dd_XY(t, g, h, m, x0, p, w, J1, J3, the, phi, psi, z1, z2, z3, p_psi, J1_, K),
#     107         Identity(z3),
#     108         psi_dd_XY(t, g, h, m, x0, p, w, J1, J3, the, phi, psi, z1, z2, z3, p_psi, J1_, K),
#     109     ])
#
# File ~/Documents/venvL3/envL3/Stage L3/Stage-LPENS/TheEND/GyroSolver.py:19, in phi_dd_XY(t, g, h, m, x0, p, w, J1, J3, the, phi, psi, the_d, phi_d, psi_d, p_psi, J1_, K)
#      16 '''Docstring to do.'''
#      18 phi_dd_free = - (2*the_d*phi_d / np.tan(the)) + (p_psi*the_d)/(J1_ * np.sin(the))
# ---> 19 phi_dd_forced = K * np.cos(w*t+p - phi) / (J1_ * np.sin(the))
#      20 phi_dd = phi_dd_free + phi_dd_forced
#      22 return phi_dd
#
# KeyboardInterrupt:

# %%
plt.imshow(tab_theta - tab_theta2)
plt.colorbar()

# %% [markdown]
# ## Forçage X :

# %%
CI = [0.001, 0, 0, 0, 0, 2*np.pi*100]


tab_t_burst = np.linspace(0, 15, 51, endpoint=True)
tab_freq = np.linspace(0.52, 0.54, 51, endpoint=True)
#print(tab_freq)
#print(len(tab_freq))
print('Estimated time (s) :', len(tab_freq) * len(tab_t_burst) * 0.15)

t1 = time()
tab_theta_X, list_the_X, list_t_X = Rabi_Chevron(tab_freq, tab_t_burst, params_f, CI, forcing='X')
t2 = time()
print(t2 - t1)

plt.figure(figsize=[10,10])
plt.imshow(np.cos(tab_theta))
plt.colorbar()
plt.xticks(np.arange(0, 51, 5), tab_t_burst[np.arange(0, 51, 5)].astype(int) ) 
plt.yticks(np.arange(0, 51, 5), tab_freq[np.arange(0, 51, 5)].round(4) ) 
plt.xlabel(r'$t_\text{burst} \; (s)$')
plt.ylabel(r'$f_\text{exc} \; (s^{-1})$')
plt.show()

# %%
CI = [np.pi - 0.001, 0, 0, 0, 0, 2*np.pi*100]


tab_t_burst = np.linspace(0, 15, 51, endpoint=True)
tab_freq = np.linspace(0.52, 0.54, 51, endpoint=True)
#print(tab_freq)
#print(len(tab_freq))
print('Estimated time (s) :', len(tab_freq) * len(tab_t_burst) * 0.15)

t1 = time()
tab_theta2_X, list_the2_X, list_t2_X = Rabi_Chevron(tab_freq, tab_t_burst, params_f, CI, forcing='X')
t2 = time()
print(t2 - t1)

plt.figure(figsize=[10,10])
plt.imshow(np.cos(tab_theta))
plt.colorbar()
plt.xticks(np.arange(0, 51, 5), tab_t_burst[np.arange(0, 51, 5)].astype(int) ) 
plt.yticks(np.arange(0, 51, 5), tab_freq[np.arange(0, 51, 5)].round(4) ) 
plt.xlabel(r'$t_\text{burst} \; (s)$')
plt.ylabel(r'$f_\text{exc} \; (s^{-1})$')
plt.show()

# %%
plt.imshow(tab_theta - tab_theta_X)
plt.colorbar()

# %%
plt.imshow(tab_theta2 - tab_theta2_X)
plt.colorbar()

# %% [markdown]
# # Test Asymétrique :

# %%
CI = [0.001, 0, 0, 0, 0, 2*np.pi*100]


g = 9.81
m = 0.375
J3 = 0.000055
J1 = 0.000055
h = 31.25 * 1e-3
x0 = 15 * 1e-2

p_psi_exp = CI[-1] * J3


#omega_f =  0.265

omega_f = m * g * h / (p_psi_exp)

params_f = [g, m, h, J1, J3, x0, -np.pi,  omega_f / (2 * np.pi)]


print(f'Larmor Pulsation (th) : {omega_f : >+20_.3f}')
print(f'Larmor Frequency (th) : {omega_f/(2*np.pi) : >+20_.3f}')
print(f'Larmor Period (th) : {2 * np.pi / omega_f : >+20_.3f}')

omega_R_th = -0.5 * np.cos(params_f[-2]) * (m * h * x0 * (omega_f**2)) / p_psi_exp
#omega_R_th = -0.5 * np.cos(params_f[-2]) * ( (m*h)**3 * g**2 * x0) / (p_psi_exp**3)

print(f'Rabi Frequency (th) : {omega_R_th : >+20_.3f}')
print(f'Rabi Period (th) : {2 * np.pi / omega_R_th : >+20_.3f}')
print(f'Temps de montée (th) : {np.pi / omega_R_th : >+20_.3f}')


rapport_freq = float(omega_f / omega_R_th)
print(f'Rapport des pulsations Larmor/Rabi : {rapport_freq : >+20_.3f}')


params_f[-1] = 0.53


t1 = time()
t, the, phi, psi, the_d, phi_d, psi_d = Solve_Gyro_Forced(0, 18, CI, params_f, solving_method='RK23')

t2 = time()
print('Temps de résolution', t2 - t1)

plt.figure()
plt.plot(t, the * 180 / np.pi, 'r', label='Product')
plt.xlabel(r'time $t \; (s)$')
plt.ylabel(r'$\theta \; (^\circ)$')
plt.legend()
plt.show()
# Out:
# Larmor Pulsation (th) :               +3.327
# Larmor Frequency (th) :               +0.529
# Larmor Period (th) :               +1.889
# Rabi Frequency (th) :               +0.281
# Rabi Period (th) :              +22.324
# Temps de montée (th) :              +11.162
# Rapport des pulsations Larmor/Rabi :              +11.819
# Temps de résolution 0.3133561611175537

# %%
tab_freq_sweep = np.arange(0.52, 0.54, 0.00005) 
print('Estimated time :', len(tab_freq_sweep) * 0.3)

f_max, exc_freq, tab_theta, tab_theta_min, tab_t = Frequency_Sweep_MIN(tab_freq_sweep, params_f, tf=18 ,
                        CI = CI, solving_method='RK23', plot=True)
# Out:
# Estimated time : 120.3

# %%
tab_freq_sweep = np.arange(0.52, 0.54, 0.00005) 
print('Estimated time :', len(tab_freq_sweep) * 0.3)

f_max, exc_freq, tab_theta, tab_theta_min, tab_t = Frequency_Sweep_MIN(tab_freq_sweep, params_f, tf=25 ,
                        CI = CI, solving_method='RK23', plot=True)
# Out:
# Estimated time : 120.3
