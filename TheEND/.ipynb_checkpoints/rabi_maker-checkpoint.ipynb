# %%
from GyroSolver import *
import numpy as np
import matplotlib.pyplot as plt

# %%
g = 9.81           # m/s^2
m = 0.375          # kg
J3 = 0.000055      # kg.m^2
J1 = 0.000055      # kg.m^2
h = 31.25 * 1e-3   # m
x0 =  0.1
f_exc = 1.059
p = np.pi

params = [g, m, h, J1, J3, x0, p, f_exc]
CI = [0.0001, 0, 0, 0, 0, 2 * np.pi * 50]

Gyro_Carac_Values(params, CI)
# Out:
# Larmor Pulsation (th) :               +6.653
# Larmor Frequency (th) :               +1.059
# Larmor Period (th) :               +0.944
#
# Rabi Pulsation (th) :               +1.501
# Rabi Period (th) :               +4.185
# Temps de montée (th) :               +2.092
#
# Rapport des pulsations Larmor/Rabi :               +4.431
#
# Rapport Approx Gyroscopique :             +932.056

# %%
larmor_frequency = 1.059
rabi_frequency = larmor_frequency / 4.431

# %%
tab_t_burst = np.linspace(0, 20, 31, endpoint=True)

delta = np.linspace(-0.3, 0.3, 31, endpoint=True)

exc_freq = delta + larmor_frequency

tab_t_burst_mesh, exc_freq_mesh = np.meshgrid(tab_t_burst, exc_freq, sparse=True)


chevron = Rabi_Chevron_Maker(1, 1, params, CI, solving_method='RK23', forcing='X')

# %%
def aux(x, y):
    return Rabi_Chevron_Maker(x, y, params, CI, solving_method='RK23', forcing='X')

# %%
aux2 = np.vectorize(aux)

# %%
test = aux2(tab_t_burst_mesh, exc_freq_mesh)
# Out:
# /Users/bradaizakaria/Documents/venvL3/envL3/lib/python3.11/site-packages/scipy/integrate/_odepack_py.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %%
plt.figure(figsize=(4, 3), dpi = 300)
plt.imshow(test, origin = "lower", extent=[0, 20, 0.75, 1.35], aspect="auto")
plt.xlabel("Durée de l'excitation [s]")
plt.ylabel("Désaccord [Hz]")
plt.colorbar()
plt.savefig("Rabi_test.png")
plt.show()
