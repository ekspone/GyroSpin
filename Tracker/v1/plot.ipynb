# %%
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
t, x, y = np.loadtxt("position.csv", delimiter= ";").T

# %%
plt.plot(x, y, "k--", lw=0.5, zorder=1)
plt.scatter(x, y, c = t, lw=3, zorder=2)
