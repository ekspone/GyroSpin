# %%
#%%timeit -r 1 -n 2
from Mvt_Equations import *
import numpy as np
import matplotlib.pyplot as plt
from time import time

# %%
CI = [np.pi / 24, 0, 0, 0, 0, 2*np.pi*50]

t = np.linspace(0, 200, 1000000)

g = 9.81
m = 0.375
J3 = 0.000055
J1 = 0.000055
h = 31.25 * 1e-3
x0 = 10 * 1e-2

omega_f =  0.265 * 4
params_f = [g, m, h, J1, J3, x0, np.pi,  omega_f]

# %%
t1 = time()
t, the, phi, psi, the_d, phi_d, psi_d = Solve_Gyro_Forced_Fast(0, 90, CI, params_f, solving_method='RK23')
t2 = time()
print(t2 - t1)
print(len(t))
plt.figure()
plt.plot(t, the * 180 / np.pi)
plt.show()
# Out:
# 1.8720083236694336
# 5546

# %% [markdown]
# -------
#
# # Trying to make Rabi's Chevrons :

# %%
tab_t_burst = np.linspace(0, 10, 51, endpoint=True)
tab_freq = np.linspace(0.24, 0.28, 41, endpoint=True)
print(tab_freq)
tab_freq = tab_freq * 4
print(len(tab_freq))
print('Estimated time (s) :', len(tab_freq) * 10)
# Out:
# [0.24  0.241 0.242 0.243 0.244 0.245 0.246 0.247 0.248 0.249 0.25  0.251
#  0.252 0.253 0.254 0.255 0.256 0.257 0.258 0.259 0.26  0.261 0.262 0.263
#  0.264 0.265 0.266 0.267 0.268 0.269 0.27  0.271 0.272 0.273 0.274 0.275
#  0.276 0.277 0.278 0.279 0.28 ]
# 41
# Estimated time (s) : 410

# %%
t1 = time()
tab_theta, list_the, list_t = Rabi_Chevron(tab_freq, tab_t_burst, params_f, CI)
t2 = time()
print(t2 - t1)
# Out:
# 433.4194710254669

# %%
plt.figure()
plt.imshow(np.cos(tab_theta))
plt.colorbar()
plt.show()

# %%
plt.figure()
plt.imshow(np.cos(tab_theta))
plt.colorbar()
plt.show()
