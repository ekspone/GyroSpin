# %%
import numpy as np
import matplotlib.pyplot as plt
from Mvt_Equations import *
from time import time

# %%
CI = [np.pi / 12, 0, 0, 0, 0, 2*np.pi*100]

t = np.linspace(0, 200, 1000000)

g_ = 9.81
m_ = 0.375
J3_ = 0.000055
J1_ = 0.000055
h_ = 31.25 * 1e-3
x0_ = 10 * 1e-2

omega_f =  0.53
params_f = [g_, m_, h_, J1_, J3_, x0_, np.pi,  omega_f]

# %%
dt1 = time()

t, the, phi, psi, the_d, phi_d, psi_d = Solve_Gyro_Forced_Fast(0, 100, CI, params_f, solving_method='RK23')
plt.figure()
plt.plot(t, the* 180 / np.pi)
plt.show()
dt2 = time()
print(dt2 - dt1)
# Out:
# 2.6677908897399902

# %%
f1 = 0.525
step_f = 0.00005
f2 = 0.535 - step_f
x1 = 2.5
x2 = 7.5
step_x = 2.5
print(Frequency_array(f1, f2, step_f))
print('Temps estimé =', len(Frequency_array(f1, f2, step_f)) * 5 / 3 )
print(Amplitude_array(x1, x2, step_x))
# Out:
# [0.525   0.52505 0.5251  0.52515 0.5252  0.52525 0.5253  0.52535 0.5254
#  0.52545 0.5255  0.52555 0.5256  0.52565 0.5257  0.52575 0.5258  0.52585
#  0.5259  0.52595 0.526   0.52605 0.5261  0.52615 0.5262  0.52625 0.5263
#  0.52635 0.5264  0.52645 0.5265  0.52655 0.5266  0.52665 0.5267  0.52675
#  0.5268  0.52685 0.5269  0.52695 0.527   0.52705 0.5271  0.52715 0.5272
#  0.52725 0.5273  0.52735 0.5274  0.52745 0.5275  0.52755 0.5276  0.52765
#  0.5277  0.52775 0.5278  0.52785 0.5279  0.52795 0.528   0.52805 0.5281
#  0.52815 0.5282  0.52825 0.5283  0.52835 0.5284  0.52845 0.5285  0.52855
#  0.5286  0.52865 0.5287  0.52875 0.5288  0.52885 0.5289  0.52895 0.529
#  0.52905 0.5291  0.52915 0.5292  0.52925 0.5293  0.52935 0.5294  0.52945
#  0.5295  0.52955 0.5296  0.52965 0.5297  0.52975 0.5298  0.52985 0.5299
#  0.52995 0.53    0.53005 0.5301  0.53015 0.5302  0.53025 0.5303  0.53035
#  0.5304  0.53045 0.5305  0.53055 0.5306  0.53065 0.5307  0.53075 0.5308
#  0.53085 0.5309  0.53095 0.531   0.53105 0.5311  0.53115 0.5312  0.53125
#  0.5313  0.53135 0.5314  0.53145 0.5315  0.53155 0.5316  0.53165 0.5317
#  0.53175 0.5318  0.53185 0.5319  0.53195 0.532   0.53205 0.5321  0.53215
#  0.5322  0.53225 0.5323  0.53235 0.5324  0.53245 0.5325  0.53255 0.5326
#  0.53265 0.5327  0.53275 0.5328  0.53285 0.5329  0.53295 0.533   0.53305
#  0.5331  0.53315 0.5332  0.53325 0.5333  0.53335 0.5334  0.53345 0.5335
#  0.53355 0.5336  0.53365 0.5337  0.53375 0.5338  0.53385 0.5339  0.53395
#  0.534   0.53405 0.5341  0.53415 0.5342  0.53425 0.5343  0.53435 0.5344
#  0.53445 0.5345  0.53455 0.5346  0.53465 0.5347  0.53475 0.5348  0.53485
#  0.5349  0.53495 0.535  ]
# Temps estimé = 335.0
# [2.5 5.  7.5]

# %%
dt1 = time()

f_max, exc_freq, tab_theta, tab_theta_max, tab_t = Frequency_Sweep(f1, f2, step_f, params_f, tf=50, CI=CI)

dt2 = time()
print(dt2 - dt1)
# Out:
# 301.67102313041687

# %%
print(f_max)
# Out:
# [0.52855]

# %%
np.max(tab_theta_max)
# Out:
# 179.93075232953078

# %%
params_f[-3] = 5 * 1e-2

dt1 = time()

f_max, exc_freq, tab_theta, tab_theta_max, tab_t = Frequency_Sweep(f1, f2, step_f, params_f, tf=50, CI=CI)

dt2 = time()
print(dt2 - dt1)
# Out:
# 338.7745089530945

# %%
print(f_max)
# Out:
# [0.52895]

# %%
params_f[-3] = 7.5 * 1e-2

dt1 = time()

f_max, exc_freq, tab_theta, tab_theta_max, tab_t = Frequency_Sweep(f1, f2, step_f, params_f, tf=50, CI=CI)

dt2 = time()
print(dt2 - dt1)
# Out:
# 313.65527868270874

# %%
print(f_max)
# Out:
# [0.5288]

# %%
params_f[-3] = 10 * 1e-2

dt1 = time()

f_max, exc_freq, tab_theta, tab_theta_max, tab_t = Frequency_Sweep(f1, f2, step_f, params_f, tf=50, CI=CI)

dt2 = time()
print(dt2 - dt1)
# Out:
# 302.3971481323242

# %%
print(f_max)
# Out:
# [0.52855]

# %%
tab_x0_forc = [2.5, 5, 7.5, 10]
tab_f_max_forc = [0.52855, 0.52895, 0.5288 ,0.52855]
plt.figure()
plt.scatter(tab_x0_forc, tab_f_max_forc)

# %%
plt.figure()
plt.plot(tab_t[2], tab_theta[2] * 180/np.pi)

# %%
f_max2, exc_freq2, tab_x2, tab_theta2, tab_theta_max2, tab_t2 = Double_Sweep(f1, f2, step_f, x1, x2, step_x, params_f, tf=200)

# %%
f_max2

# %%
plt.figure()
plt.scatter(exc_freq2, tab_theta_max2[0], marker='o')
plt.xlabel(r"$f \; (\mathrm{Hz})$")
plt.ylabel(r"$\theta_\mathrm{max} \; (\mathrm{deg})$")

# %%
plt.figure()
plt.plot(tab_x2, f_max2)

# %%
plt.figure()
plt.plot(tab_t2[0, -1], tab_theta2[0, -1] * 180/np.pi)
